# %% [markdown]
# <a href="https://colab.research.google.com/github/uneconomicalfairy14/samvadhini/blob/dev/similar_words_spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U spacy
# Out:
# ...
#      |████████████████████████████████| 6.2 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 181 kB 45.7 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 457 kB 44.3 MB/s
# ...
#      |████████████████████████████████| 653 kB 45.1 MB/s
# ...
#      |████████████████████████████████| 10.1 MB 29.9 MB/s
# ...
#      |████████████████████████████████| 58 kB 5.8 MB/s
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.2.0
#     Uninstalling typing-extensions-4.2.0:
#       Successfully uninstalled typing-extensions-4.2.0
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: smart-open
# ...

# %%
# !python -m spacy download en
# Out:
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# ...
#      |████████████████████████████████| 12.8 MB 6.0 MB/s
# ...
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

# %%
import nltk

# %%
import time

# %%
nlp = spacy.load("en_core_web_sm")

# %%
list_ = ["erp","gradecard","revaluation","provisional degree certificate","duplicate gradecard","consolidated gradecard","bonafide certificate","attestation","prn","refund","rechecking"]

# %%
input_query = "My creditcard is lost"

# %%
dup_input_query = input_query

# %%
flag = nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
try:
    import string
    from nltk.corpus import stopwords
    import nltk
except Exception as e:
    print(e)


class PreProcessText(object):

    def __init__(self):
        pass

    def __remove_punctuation(self, text):
        """
        Takes a String
        return : Return a String
        """
        message = []
        for x in text:
            if x in string.punctuation:
                pass
            else:
                message.append(x)
        message = ''.join(message)

        return message

    def __remove_stopwords(self, text):
        """
        Takes a String
        return List
        """
        words= []
        for x in text.split():

            if x.lower() in stopwords.words('english'):
                pass
            else:
                words.append(x)
        return words


    def token_words(self,text=''):
        """
        Takes String
        Return Token also called  list of words that is used to
        Train the Model
        """
        message = self.__remove_punctuation(text)
        words = self.__remove_stopwords(message)
        return words

# %%
if(flag == "False" or flag == False):
  print("failed")
else:
  print("download")
  helper = PreProcessText()
  words = helper.token_words(text=input_query)
# Out:
# download

# %%
words
# Out:
# ['creditcard', 'lost']

# %%
start = time.time()
sim = 0
changed_word = ""
for i in list_:
  list_element = i
  data1 = nlp(list_element)
  for j in words:
    input_words = j
    data2 = nlp(input_words)
    # if data1.similarity(data2) >0.7:
      # print(data1.similarity(data2))
      # input_words.replace(j,i)
    if sim < data1.similarity(data2):
      sim = data1.similarity(data2)
      changed_word = i 
      x = input_query.replace(j,changed_word)

    print(j," ",i," ",data1.similarity(data2))
    print(changed_word)
end = time.time()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   del sys.path[0]
# ...

# %%
print("Original input : ",dup_input_query,"\nChanged input : ",x)
# Out:
# Original input :  My creditcard is lost
# Changed input :  My gradecard is lost

# %%
print("Time : ",end-start)
# Out:
# Time :  0.3605477809906006

# %% [markdown]
# ##NEW WORKING

# %%
# !pip install syllables

# %%
import syllables

# %%
process_list = "faq question What if I need to know my correct CGPA? I have cleared my backlog but the result sheet does not show GPA and CGPA. Why? I have cleared my backlog, but the result on ERP is not updated .It still shows earlier CGPA. As a result, it is affecting my CGPA What do I do if I have not received my grade card? My name/Father's Name/Mother's name is incorrect on grade card. How do I get it corrected? How can I get a new copy of corrected grade cards? From where should I collect the corrected grade cards/PDC? In how many days will I get the corrected grade cards?Do I need to submit an Exam form for the end term exam?I have an internal backlog, do I need to submit an exam form?I have paid all my outstanding fees, do I still have to submit the exam form?How can I know whether I have an internal backlog or external backlog?What if I was unable to fill the exam form in time?Do I have to pay exam fees for regular and backlog separately?How to fill an Examination form?I have not got my hall ticket. What should I do?I have lost my hall ticket. What is the process for obtaining a duplicate hall ticket ?My photograph is not seen on hall ticket. What do I need to do?The course for which I have to appear for, is not seen in the hall ticket. Please tell what should be done ‚ My result is not visible on ERP. It says Result is withheld. Contact Examination Department. What is the reason?I have paid my instalment. Yet, why is my result withheld?When will I get my result in ERP?I received my result and have been given Grade F in a subject. How can I know the external marks obtained in the subject?I want to give my paper for re-checking/revaluation. What is the procedure?How can I know my internal and external marks obtained in a particular subject?What is the procedure to obtain a photocopy of answer booklet?What is the process of revaluation ? How to upload the form and pay fees?How to apply for revaluation and retotalling?Where should I submit the revaluation fee?When will the revaluation results be declared?I have already paid the revaluation fees. But in ERP, it is seen as outstanding. What is the reason?I have to apply for revaluation but subject is not seen in re-evaluation list. What could be the reason?Why is it that the payment done for revaluation not being reflected on my ERP payment section?How do I apply for Provisional Degree Certificate?From where and when should I collect the Provisional Degree Certificate?I have lost my grade card? Can I get another copy of grade card?How do I apply for a duplicate grade card?What documents are required while applying for the duplicate grade card?What are the charges for obtaining a duplicate grade card?What is the mode of payment for Duplicate grade card?When and how will I receive the duplicate grade card?If I find the original document after I obtain the duplicate, can I use the originalone?Can I get backlog and regular result on a single grade card?What is a consolidated grade card?How is a Consolidated Grade Card different from a transcript?How do I apply for a consolidated grade card?What documents are required while applying for the consolidated grade card?What are the charges for obtaining a consolidated grade card?What is the mode of payment for consolidated grade card?I need to submit a Course completion certificate in my Company. What is theprocedure?In how many days, can I get the Certificate?Will I get a soft copy/hard copy of the Certificate?faq I require a Bonafide certificate. What is the procedure to obtain it ?In how many days, can I get the Bonafide Certificate?Will I get a soft copy/hard copy of the Bonafide Certificate?I require a letter stating that medium of instruction for my course was English. What is the procedure?In how many days, can I get the Ã¢â‚¬ËoeMedium of InstructionÃ¢â‚¬â„¢ Certificate?Will I get a soft copy/hard copy of the Medium of Instruction Certificate?How do I apply for Equivalent Percentage Certificate?In how many days, can I get the Equivalent Percentage Certificate?Will I get a soft copy/hard copy of the Equivalent Percentage Certificate?What documents are required for applying for a trimester to semester conversion certificate?What are the charges for trimester to semester conversion certificate?What is the mode of payment for trimester to semester conversion certificate?In how many days can I get the trimester to semester conversion certificate?From where do I collect the trimester to semester conversion certificate?What is an official transcript?What documents are required for applying for a transcript?How do I apply for a transcript?What are the charges for applying for an official transcript?What is the mode of payment for a transcript?In how many days can I receive the transcript after application?Will I get a soft copy/hard copy of the transcript?Why are transcripts sent in sealed and signed envelope?I want the University to send the transcript to WES, Canada ? What is the procedure for it?What are the charges for transcript?How should I do the payment for MITSOB transcript?I want the University to send the transcript to WES, Canada ? What is theprocedure?How much time will it take to process the transcript?How do I collect the MITSOB transcript?What are the postal charges for MITSOB transcript? How do I do the payment ?I have paid exam fees twice. How do I apply for refund of the exam fees?I have done excess payment for transcript. How can I get refund?Is it compulsory to register for the Convocation ? Can I collect my Degree Certificate, in person? From where should I collect it ?Can any of my family member collect Degree Certificate on my behalf?I have registered and attended Convocation. However, due to some documents pending from my end, I had not received I need a set of grade cards attested? How do I proceed? Can I get my result on ERP attested?In how many days can I get it attested?faq answerCGPA is seen on the grade card. The CGPA count can be verified by referring to the passing criteria mentioned in GPA and CGPA are not mentioned on backlog grade cards. GPA, CGPA will be highlighted on regular trimester grade card Grade card shows first attempt GPA and CGPA only. Hence, even if you have cleared backlog, improved CGPA for that trimester Grade cards should be collected from the student section of your Department. If your grade card is not available at the student Name correction on grade cards/PDC needs to be done in ERP at the office of student section of your Department. Kindly Once the required corrections are done in ERP, You can apply for corrected grade cards by filling and sending the You have to collect the corrected grade cards/PDC from Department of Examination.Processing of correction on grade cards will take minimum 4 working days after you submit all the required documents at Yes, it is necessary to fill exam form for every end term exam.Yes, it is necessary to fill exam form for internal backlog also.You are required to submit an exam form. There is no connection between outstanding fees and an exam form.After you fill and submit the exam form, you should download the PDF of your application which shows you the details of It is mandatory to fill the exam form within the stipulated time only. Under any circumstances, you will not be allowed to fill No, Regular and Backlog fees have to be paid together.Examination related queries (Applicable for Offline End Term Exam) Select Exam, Course Year and Click on Show. Submit the application and take printout of your exam application form. Submit Probable reasons1) Student has not filled exam form.2) Subject Mapping might not be done from Institute.3) Any other technical Fill the student assistance form and pay fine at Exam Department.Paste I-Card size photograph on hall ticket and get it duly attested from Department of Examination.Contact Examination Department for clarification.Result related queriesThis message occurs because your result is withheld due to non-submission of eligibility documents, outstanding fees, etc. Your result may be withheld for any administrative issue. Contact student section for clarification.Your result will be seen in ERP only after a release order is received from the student section.Mail your query to exam.helpdesk@mitwpu.edu.in and attach screenshot of result.There is no rechecking/revaluation for online exams.Mail your query details to exam.helpdesk@mitwpu.edu.in for knowing the external marks in the mentioned subject. For your Pay the required fee at Department of Examination and fill student assistance form. Photocopy will be made available within In student module, Click on University examination. Select application form and enter necessary information. Take printout In student module, select University Examination, click on application, Mention exam typeand exam.Fees to be paid online in ERP.Revaluation result will be declared after 12 Days from application of revaluation.The amount must have been deducted against any other outstanding fee. Contact student section for clarification.Either the student was absent for that particular subject or result is withheld from student section, hence subject shall not Contact student section for clarificationYou don't have to apply separately for a Provisional Degree Certificate. It will be issued after you have successfully completed Provisional Degree Certificate will be given from the student section after 15 days from date of declaration of your final trimester Grade card is issued only once. In case, you have lost your grade card, you can apply for a duplicate grade card only.You have to fill and submit application form for issuing of duplicate grade card which is available on the website(https://mitwpu.FIR copy, Affidavit on Rs.100/- stamp paper giving details and receipt of fee for duplicategrade card.Fee of Rs.500/- + Rs. 100/- per trimester grade card.You must pay online. Payment details are mentioned on website (https://mitwpu.edu.in/examination). Send the creenshot You will have to collect it from Department of Examination after 15 days of application.Once you have obtained a duplicate in place of a lost document, always use the duplicate document. If the original document Yes, you can apply for a consolidated grade card. A consolidated grade card will show consolidated result of a trimester (Regular & cleared backlog together).It shows revised Consolidated grade card shows revised result of only one trimester with revised GPA where as a transcript is a document You have to fill and submit application form for issuing of consolidated grade card which is available on the website (https://Application form for consolidated grade card, scan copy of regular and backlog grade cards of trimester for which consolidated Processing fee for one consolidated grade card is Rs.200/-You must pay online. Payment details are mentioned on website (https://mitwpu.edu.in/examination). Send the screenshot You must fill the student assistance form.(https://mitwpu.edu.in/images/documents/Student-Assistant-Form.pdf) The course completion certificate will be issued after minimum 5 working days from date of application.The soft copy of the Certificate will be provided, only if required. You must collect the hard copy from Department of Examination faq You should fill the student assistance form (https://mitwpu.edu.in/images/documents/Student-Assistant-Form.pdf) Processing of Bonafide certificate requires minimum 5 working days from date of application.The soft copy of Bonafide certificate will be provided, only if required. You must collect the hard copy from Department of You can apply for Ã¢â‚¬ËoeMedium of InstructionÃ¢â‚¬â„¢ Certificate.. Fill student assistance form and mail to exam.helpdesk@Letter of Ã¢â‚¬ËoeMedium of InstructionÃ¢â‚¬â„¢ will be issued after minimum 5 working days from date of application.Soft copy will be provided, if required. You must collect the hard copy from Department of Examination within a week after The Certificate for Equivalent Percentage is available on website (https://mitwpu.edu.in/images/documents/EQUIVALENT-Equivalent Percentage Certificate will be issued after minimum 5 working days from date of application.Soft copy of Equivalent Percentage Certificate will be provided, if required. You must collect the hard copy from Department Documents required are scan copy of grade cards of the year for which conversion is required, student assistance form The processing charges for one trimester to semester conversion certificate are Rs.250/-Do online payment. The payment details are mentioned on the website.(https://mitwpu.edu.in/examination/contact).Mail The processing of trimester to semester conversion certificate takes minimum 5 working days from date of application with You should collect the trimester to semester conversion certificate from Department of Examination within a week after it is An official transcript is an authentic document that includes updated results of all trimesters declared till date of application The documents required for applying for a transcript are scan copy of recent trimester grade card, application form for issuing Send screenshot of payment for transcript along with the application form (https://mitwpu.edu.in/images/documents/Application-The processing charges for transcript are Rs.200/- for one copy of transcript. If the transcript is to be sent on postal address Do online payment for transcript. The payment details are mentioned on the website.(https://mitwpu.edu.in/examination/contact). Processing of transcript takes minimum 5 working days from date of application with all required documents.Soft copy of the transcript will be sent, only if required. You should collect the hard copy of the transcript from Department This is done in order to assure the recipient of the document that the transcript is genuine.Postal charges to Canada Rs.1600/-. Do payment online .Payment details mentioned on website.(https://mitwpu.edu.in/examination/Processing charges for MITSOB transcript differ batchwise. Send mail to exam.helpdesk@mitwpu.edu.in and mention You must pay online for the transcript. Payment details are mentioned on website (https://mitwpu.edu.in/examination). Send The postal charges to Canada Rs.1600/-. Do payment online .Payment details are mentioned on the website. Send duly filled Transcript processing takes 8 days after receipt of application with all required documentsTranscript can be collected from Department of Examination or it can be sent at your postal address.Postal charges (within India only ) for MITSOB transcript are Rs.500/- .You must do online payment. The payment details Send an application to exam.helpdesk@mitwpu.edu.in along with Bank Details (Name, Bank Name, Branch, Account number, Send an application to exam.helpdesk@mitwpu.edu.in along with Bank Details (Name, Bank Name. Branch, Account number, Yes, it is compulsory to register for Convocation as per instructions and payment of registration fees.Yes, you may collect your Degree Certificate from Department of Examination.Yes, that is permissible, provided you send authority letter 2 days in advance to Department of Examination via mail to exam.At first, you must complete the formalities related to issues pending at your end. Then fill student assistance form (https://You have to fill the student assistance form (https://mitwpu.edu.in/imapes/documents/Student-Assistant-Form.No. Results on ERP will not be attested.You will get the grade cards attested in 2 working days.faq categorygrade cardgrade cardgrade cardgrade cardCorrections on grade card /PDCCorrections on grade card /PDCCorrections on grade card /PDCCorrections on grade card /PDCExam Form IssuesExam Form IssuesExam Form IssuesExam Form IssuesExam Form IssuesExam Form IssuesExamination related queries (Applicable for Offline End Term Exam)Examination related queries (Applicable for Offline End Term Exam)Examination related queries (Applicable for Offline End Term Exam)Examination related queries (Applicable for Offline End Term Exam)Examination related queries (Applicable for Offline End Term Exam)Result related queriesResult related queriesResult related queriesResult related queriesRechecking and Revaluation (Applicable for Offline End-Term Exams)Result related queriesRechecking and Revaluation (Applicable for Offline End-Term Exams)Rechecking and Revaluation (Applicable for Offline End-Term Exams)Rechecking and Revaluation (Applicable for Offline End-Term Exams)Rechecking and Revaluation (Applicable for Offline End-Term Exams)Rechecking and Revaluation (Applicable for Offline End-Term Exams)Rechecking and Revaluation (Applicable for Offline End-Term Exams)Rechecking and Revaluation (Applicable for Offline End-Term Exams)Rechecking and Revaluation (Applicable for Offline End-Term Exams)Provisional Degree CertificateProvisional Degree CertificateDuplicate Grade CardDuplicate Grade CardDuplicate Grade CardDuplicate Grade CardDuplicate Grade CardDuplicate Grade CardDuplicate Grade CardConsolidated grade cardConsolidated grade cardConsolidated grade cardConsolidated grade card Consolidated grade card Consolidated grade card Consolidated grade card Course completion certificate Course completion certificate Course completion certificate faq Bonafide certificate Bonafide certificate Bonafide certificate Medium of Instruction Certificate Medium of Instruction Medium of Instruction Equivalent Percentage Certificate Equivalent Percentage Certificate Equivalent Percentage Certificate Trimester to semester conversion certificate Trimester to semester conversion certificate Trimester to semester conversion certificate Trimester to semester conversion certificate trimester to semester conversion certificate Transcript  transcript Transcript Transcript Transcript Transcript Transcript Transcript MITSOB Transripts to WES MITSOB Transripts to WES MITSOB Transripts to WES MITSOB Transripts to WES MITSOB Transripts to WES MITSOB Transripts to WES MITSOB Transripts to WES Refund Queries Refund QueriesDegree CertificateDegree CertificateDegree Certificate Degree Certificate Attestation of Grade Cards Attestation of Grade Cards Attestation of Grade Cards"

# %%
try:
    import string
    from nltk.corpus import stopwords
    import nltk
except Exception as e:
    print(e)


class PreProcessText(object):

    def __init__(self):
        pass

    def __remove_punctuation(self, text):
        """
        Takes a String
        return : Return a String
        """
        message = []
        for x in text:
            if x in string.punctuation:
                pass
            else:
                message.append(x)
        message = ''.join(message)

        return message

    def __remove_stopwords(self, text):
        """
        Takes a String
        return List
        """
        words= []
        for x in text.split():

            if x.lower() in stopwords.words('english'):
                pass
            else:
                words.append(x)
        return words


    def token_words(self,text=''):
        """
        Takes String
        Return Token also called  list of words that is used to
        Train the Model
        """
        message = self.__remove_punctuation(text)
        words = self.__remove_stopwords(message)
        return words

# %%
if(flag == "False" or flag == False):
  print("failed")
else:
  print("download")
  helper = PreProcessText()
  words = helper.token_words(text=process_list)
# Out:
# download

# %%
dup_removed_list = list(dict.fromkeys(words))

# %%
dup_removed_list
# Out:
# ['faq',
#  'question',
#  'need',
#  'know',
#  'correct',
#  'CGPA',
#  'cleared',
#  'backlog',
#  'result',
#  'sheet',
#  'show',
#  'GPA',
#  'ERP',
#  'updated',
#  'still',
#  'shows',
#  'earlier',
#  'affecting',
#  'received',
#  'grade',
#  'card',
#  'nameFathers',
#  'NameMothers',
#  'name',
#  'incorrect',
#  'get',
#  'corrected',
#  'new',
#  'copy',
#  'cards',
#  'collect',
#  'cardsPDC',
#  'many',
#  'days',
#  'cardsDo',
#  'submit',
#  'Exam',
#  'form',
#  'end',
#  'term',
#  'examI',
#  'internal',
#  'exam',
#  'formI',
#  'paid',
#  'outstanding',
#  'fees',
#  'formHow',
#  'whether',
#  'external',
#  'backlogWhat',
#  'unable',
#  'fill',
#  'timeDo',
#  'pay',
#  'regular',
#  'separatelyHow',
#  'Examination',
#  'got',
#  'hall',
#  'ticket',
#  'doI',
#  'lost',
#  'process',
#  'obtaining',
#  'duplicate',
#  'photograph',
#  'seen',
#  'doThe',
#  'course',
#  'appear',
#  'Please',
#  'tell',
#  'done',
#  '‚',
#  'visible',
#  'says',
# ...

# %%
print(len(dup_removed_list))
# Out:
# 489

# %%
start = time.time()
l = []
for i in dup_removed_list:
  num = syllables.estimate(i)
  print(i," ",num)
end = time.time()

print(end-start)
# Out:
# faq   1
# question   2
# need   1
# know   1
# correct   2
# CGPA   1
# cleared   2
# backlog   2
# result   2
# sheet   1
# show   1
# GPA   1
# ERP   1
# updated   3
# still   1
# shows   1
# earlier   2
# affecting   3
# received   3
# grade   2
# card   1
# nameFathers   4
# NameMothers   4
# name   1
# incorrect   3
# get   1
# corrected   3
# new   1
# copy   2
# cards   1
# collect   2
# cardsPDC   1
# many   2
# days   1
# cardsDo   2
# submit   2
# Exam   1
# form   1
# end   1
# term   1
# examI   2
# internal   3
# exam   2
# formI   1
# paid   1
# outstanding   3
# fees   1
# formHow   2
# whether   2
# external   3
# backlogWhat   3
# unable   3
# fill   1
# timeDo   3
# pay   1
# regular   3
# separatelyHow   6
# Examination   4
# got   1
# hall   1
# ticket   2
# doI   1
# lost   1
# process   2
# obtaining   3
# duplicate   4
# photograph   3
# seen   1
# doThe   2
# course   2
# appear   2
# Please   2
# tell   1
# done   1
# ‚   1
# visible   3
# says   1
# ...
