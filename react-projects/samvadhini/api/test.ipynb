# %%
import requests
import json

# %%
r=requests.post("http://127.0.0.1:5000/query",data=json.dumps({"msg":"वडिलांचा नाव कार्डवर चुकीचा आहे"}), headers={"Content-Type":"application/json"})
r.text
# Out:
# '{\n  "documents": [\n    {\n      "answer": "तुमच्या विभागातील विद्यार्थी विभागाच्या कार्यालयात ERP मध्ये ग्रेड कार्ड/PDC वर नाव दुरुस्ती करणे आवश्यक आहे. ERP मध्ये आवश्यक दुरुस्त्या करण्यासाठी कृपया विद्यार्थी विभागाच्या कार्यालयाशी संपर्क साधा. शिवाय, विद्यार्थ्याने त्यांच्या ईआरपी लॉगिनमध्ये वेळोवेळी त्याचे वैयक्तिक तपशील तपासले पाहिजेत.", \n      "question": "ग्रेड कार्डवर माझे नाव/वडिलांचे नाव/आईचे नाव चुकीचे आहे. मी ते कसे दुरुस्त करू?"\n    }, \n    {\n      "answer": "एकत्रित ग्रेड कार्ड त्रैमासिकाचा एकत्रित परिणाम दर्शवेल (नियमित आणि एकत्रित अनुशेष साफ केला जाईल). ते त्या तिमाहीसाठी सुधारित GPA दर्शवेल. तथापि, लक्षात घ्या की CGPA चा उल्लेख नाही.", \n      "question": "एकत्रित ग्रेड कार्ड म्हणजे काय?"\n    }, \n    {\n      "answer": "होय, तुम्ही एकत्रित ग्रेड कार्डसाठी अर्ज करू शकता.", \n      "question": "मला एकाच ग्रेड कार्डवर अनुशेष आणि नियमित निकाल मिळू शकतो का?"\n    }, \n    {\n      "answer": "तुम्हाला ऑनलाइन पेमेंट करावे लागेल. पेमेंट तपशील वेबसाइटवर नमूद केले आहेत (https://mitwpu.edu.in/examination). पेमेंटचा स्क्रीनशॉट exam.helpdesk@mitwpu.edu.in वर पाठवा.", \n      "question": "डुप्लिकेट ग्रेड कार्डसाठी पैसे देण्याची पद्धत काय आहे?"\n    }, \n    {\n      "answer": "तुम्हाला ऑनलाइन पेमेंट करावे लागेल. पेमेंट तपशील वेबसाइटवर नमूद केले आहेत (https://mitwpu.edu.in/examination). पेमेंटचा स्क्रीनशॉट exam.helpdesk@mitwpu.edu.in.Q वर पाठवा मला एकत्रित ग्रेड कार्ड कधी आणि कसे मिळेल?", \n      "question": "एकत्रित ग्रेड कार्डसाठी पेमेंटची पद्धत काय आहे?"\n    }, \n    {\n      "answer": "हा मेसेज येतो कारण तुमचा निकाल पात्रता दस्तऐवज, थकबाकी फी इत्यादी सादर न केल्यामुळे रोखला गेला आहे. तुम्हाला पुढील स्पष्टीकरणासाठी विद्यार्थी विभागाशी संपर्क साधण्याची आवश्यकता आहे.", \n      "question": "माझा निकाल ERP वर दिसत नाही. निकाल रोखला गेला आहे. परीक्षा विभागाशी संपर्क साधा. कारण काय आहे?"\n    }, \n    {\n      "answer": "एकत्रित ग्रेड कार्ड सुधारित GPA सह केवळ एका तिमाहीचे सुधारित परिणाम दर्शविते जेथे प्रतिलिपी एक दस्तऐवज आहे ज्यामध्ये सुधारित GPA आणि CGPA त्रैमासिकानुसार सर्व त्रैमासिकांचे अद्यतनित परिणाम समाविष्ट आहेत.", \n      "question": "एकत्रित ग्रेड कार्ड ट्रान्सक्रिप्टपेक्षा वेगळे कसे आहे?"\n    }, \n    {\n      "answer": "हॉल तिकिटावर आय-कार्ड आकाराचे छायाचित्र चिकटवा आणि ते परीक्षा विभागाकडून प्रमाणित करून घ्या.", \n      "question": "हॉल तिकिटावर माझा फोटो दिसत नाही. मला काय करावे लागेल?"\n    }, \n    {\n      "answer": "नाही. ERP वरील परिणाम प्रमाणित केले जाणार नाहीत.", \n      "question": "मला माझा निकाल ईआरपीवर साक्षांकित करता येईल का?"\n    }, \n    {\n      "answer": "ग्रेड कार्ड एकदाच दिले जाते. जर तुमचे ग्रेड कार्ड हरवले असेल तर तुम्ही फक्त डुप्लिकेट ग्रेड कार्डसाठी अर्ज करू शकता.", \n      "question": "मी माझे ग्रेड कार्ड गमावले आहे? मला ग्रेड कार्डची दुसरी प्रत मिळेल का?"\n    }\n  ]\n}\n'

# %%
# !ls
# Out:
# faq.csv  init.py  test.ipynb  translated_answers.csv

# %%
import pandas as pd

# %%
og = pd.read_csv("sample_.csv")
ta = pd.read_csv("translated_answers.csv")
og.head(5)
# Out:
#    id                                           question  \
# 0   1            What if I need to know my correct CGPA?
# 1   2  I have cleared my backlog but the result sheet...
# 2   3  I have cleared my backlog, but the result on E...
# 3   4  What do I do if I have not received my grade c...
# 4   5  My name/Father's Name/Mother's name is incorre...
#
#                                               answer  \
# 0  CGPA is seen on the grade card. The CGPA count...
# 1   GPA and CGPA are not mentioned on backlog gra...
# 2   Grade card shows first attempt GPA and CGPA o...
# 3  Grade cards should be collected from the stude...
# 4   Name correction on grade cards/PDC needs to b...
#
#                          category
# 0                      grade card
# 1                      grade card
# 2                      grade card
# 3                      grade card
# 4  Corrections on grade card /PDC

# %%
ta.head(5)
# Out:
#    id                                           question  \
# 0   0            What if I need to know my correct CGPA?
# 1   1  I have cleared my backlog but the result sheet...
# 2   2  I have cleared my backlog, but the result on E...
# 3   3  What do I do if I have not received my grade c...
# 4   4  My name/Father's Name/Mother's name is incorre...
#
#                                               answer  \
# 0  CGPA is seen on the grade card. The CGPA count...
# 1   GPA and CGPA are not mentioned on backlog gra...
# 2   Grade card shows first attempt GPA and CGPA o...
# 3  Grade cards should be collected from the stude...
# 4   Name correction on grade cards/PDC needs to b...
#
#                          category  \
# 0                      grade card
# 1                      grade card
# 2                      grade card
# 3                      grade card
# 4  Corrections on grade card /PDC
#
#                                         answer_hindi  \
# 0  ग्रेड कार्ड पर सीजीपीए लिखा होता है। परीक्षा अ...
# 1  बैकलॉग ग्रेड कार्ड पर जीपीए और सीजीपीए का उल्ल...
# 2  ग्रेड कार्ड केवल पहला प्रयास GPA और CGPA दिखात...
# 3  ग्रेड कार्ड आपके विभाग के छात्र अनुभाग से एकत्...
# 4  आपके विभाग के छात्र अनुभाग के कार्यालय में ईआर...
#
#                                       answer_marathi
# 0  ग्रेड कार्डवर CGPA दिसतो. परीक्षा अध्यादेश 202...
# 1  बॅकलॉग ग्रेड कार्डवर GPA आणि CGPA नमूद केलेले ...
# 2  ग्रेड कार्ड प्रथम प्रयत्न GPA आणि CGPA दर्शवित...
# 3  तुमच्या विभागातील विद्यार्थी विभागाकडून ग्रेड ...
# 4  तुमच्या विभागाच्या विद्यार्थी विभागाच्या कार्य...

# %%
ta.drop('question', inplace=True, axis=1)
ta.drop('answer', inplace=True, axis=1)
ta.drop('id', inplace=True, axis=1)

# %%
ta.head(5)
# Out:
#                          category  \
# 0                      grade card
# 1                      grade card
# 2                      grade card
# 3                      grade card
# 4  Corrections on grade card /PDC
#
#                                         answer_hindi  \
# 0  ग्रेड कार्ड पर सीजीपीए लिखा होता है। परीक्षा अ...
# 1  बैकलॉग ग्रेड कार्ड पर जीपीए और सीजीपीए का उल्ल...
# 2  ग्रेड कार्ड केवल पहला प्रयास GPA और CGPA दिखात...
# 3  ग्रेड कार्ड आपके विभाग के छात्र अनुभाग से एकत्...
# 4  आपके विभाग के छात्र अनुभाग के कार्यालय में ईआर...
#
#                                       answer_marathi
# 0  ग्रेड कार्डवर CGPA दिसतो. परीक्षा अध्यादेश 202...
# 1  बॅकलॉग ग्रेड कार्डवर GPA आणि CGPA नमूद केलेले ...
# 2  ग्रेड कार्ड प्रथम प्रयत्न GPA आणि CGPA दर्शवित...
# 3  तुमच्या विभागातील विद्यार्थी विभागाकडून ग्रेड ...
# 4  तुमच्या विभागाच्या विद्यार्थी विभागाच्या कार्य...

# %%
with open('faq.csv') as infile, open('sample_.csv', 'w') as outfile:
    for idx, line in enumerate(infile):
        outfile.write(f'{idx},{line}')

# %%
ta.to_csv('updatedtrans_ans.csv', index=False)

# %%
with open('updatedtrans_ans.csv') as infile, open('indexedtrans_ans.csv', 'w') as outfile:
    for idx, line in enumerate(infile):
        outfile.write(f'{idx},{line}')

# %%
ret = pd.read_csv("sample_.csv")
trans = pd.read_csv("indexednewtrans.csv")

# %%
ret.head(5)
# Out:
#    id                                           question  \
# 0   1            What if I need to know my correct CGPA?
# 1   2  I have cleared my backlog but the result sheet...
# 2   3  I have cleared my backlog, but the result on E...
# 3   4  What do I do if I have not received my grade c...
# 4   5  My name/Father's Name/Mother's name is incorre...
#
#                                               answer  \
# 0  CGPA is seen on the grade card. The CGPA count...
# 1   GPA and CGPA are not mentioned on backlog gra...
# 2   Grade card shows first attempt GPA and CGPA o...
# 3  Grade cards should be collected from the stude...
# 4   Name correction on grade cards/PDC needs to b...
#
#                          category
# 0                      grade card
# 1                      grade card
# 2                      grade card
# 3                      grade card
# 4  Corrections on grade card /PDC

# %%
trans.head(5)
# Out:
#    id                        category  \
# 0   1                      grade card
# 1   2                      grade card
# 2   3                      grade card
# 3   4                      grade card
# 4   5  Corrections on grade card /PDC
#
#                                         answer_hindi  \
# 0  ग्रेड कार्ड पर सीजीपीए लिखा होता है। परीक्षा अ...
# 1  बैकलॉग ग्रेड कार्ड पर जीपीए और सीजीपीए का उल्ल...
# 2  ग्रेड कार्ड केवल पहला प्रयास GPA और CGPA दिखात...
# 3  ग्रेड कार्ड आपके विभाग के छात्र अनुभाग से एकत्...
# 4  आपके विभाग के छात्र अनुभाग के कार्यालय में ईआर...
#
#                                       answer_marathi
# 0  ग्रेड कार्डवर CGPA दिसतो. परीक्षा अध्यादेश 202...
# 1  बॅकलॉग ग्रेड कार्डवर GPA आणि CGPA नमूद केलेले ...
# 2  ग्रेड कार्ड प्रथम प्रयत्न GPA आणि CGPA दर्शवित...
# 3  तुमच्या विभागातील विद्यार्थी विभागाकडून ग्रेड ...
# 4  तुमच्या विभागाच्या विद्यार्थी विभागाच्या कार्य...

# %%
print(r.text)
# Out:
# {
#   "documents": [
#     {
#       "answer": "Name correction on grade cards/PDC needs to be done in ERP at the office of student section of your Department. Kindly contact the office of student section for the making the required corrections in ERP. Moreover, student must check his/her personal details from time to time in their ERP login.",
#       "question": "My name/Father's Name/Mother's name is incorrect on grade card. How do I get it corrected?"
#     },
#     {
#       "answer": "This message occurs because your result is withheld due to non-submission of eligibility documents, outstanding fees, etc. You need to contact student section for further clarification.",
#       "question": "My result is not visible on ERP. It says Result is withheld. Contact Examination Department. What is the reason?"
#     },
#     {
#       "answer": "A consolidated grade card will show consolidated result of a trimester (Regular & cleared backlog together).It shows revised GPA for that trimester. However, note that CGPA is not mentioned.",
#       "question": "What is a consolidated grade card?"
#     },
#     {
#       "answer": "An official transcript is an authentic document that includes updated results of all trimesters declared till date of application and it is signed by the Controller of Examinations.",
#       "question": "What is an official transcript?"
#     },
#     {
#       "answer": "The amount must have been deducted against any other outstanding fee. Contact student section for clarification.",
#       "question": "I have already paid the revaluation fees. But in ERP, it is seen as outstanding. What is the reason?"
#     },
#     {
#       "answer": "Do online payment for transcript. The payment details are mentioned on the website.(https://mitwpu.edu.in/examination/contact). Send the screenshot of payment to exam.helpdesk@mitwpu.edu.in",
#       "question": "What is the mode of payment for a transcript?"
#     },
#     {
#       "answer": "You  must  pay  online.  Payment  details  are  mentioned  on  website (https://mitwpu.edu.in/examination).   Send   the   screenshot   of   payment   to exam.helpdesk@mitwpu.edu.in.",
#       "question": "What is the mode of payment for Duplicate grade card?"
#     },
#     {
#       "answer": "You  must  pay  online.  Payment  details  are  mentioned  on  website (https://mitwpu.edu.in/examination).   Send   the   screenshot   of   payment   to exam.helpdesk@mitwpu.edu.in.Q When and how will I receive the consolidated grade card?",
#       "question": "What is the mode of payment for consolidated grade card?"
#     },
#     {
#       "answer": "Consolidated grade card shows revised result of only one trimester with revised GPA where as a transcript is a document that includes updated results of all trimesters with revised GPA and CGPA trimester wise.",
#       "question": "How is a Consolidated Grade Card different from a transcript?"
#     },
#     {
#       "answer": "Yes, it is compulsory to register for Convocation as per instructions and payment of registration fees.",
#       "question": "Is it compulsory to register for the Convocation ?"
#     }
#   ]
# }

# %%
r=requests.post("http://127.0.0.1:5000/query",data=json.dumps({"msg":"Father's name is wrong"}), headers={"Content-Type":"application/json"})
print(r.text)
# Out:
# {
#   "documents": [
#     {
#       "answer": "Name correction on grade cards/PDC needs to be done in ERP at the office of student section of your Department. Kindly contact the office of student section for the making the required corrections in ERP. Moreover, student must check his/her personal details from time to time in their ERP login.",
#       "question": "My name/Father's Name/Mother's name is incorrect on grade card. How do I get it corrected?"
#     },
#     {
#       "answer": "This message occurs because your result is withheld due to non-submission of eligibility documents, outstanding fees, etc. You need to contact student section for further clarification.",
#       "question": "My result is not visible on ERP. It says Result is withheld. Contact Examination Department. What is the reason?"
#     },
#     {
#       "answer": "A consolidated grade card will show consolidated result of a trimester (Regular & cleared backlog together).It shows revised GPA for that trimester. However, note that CGPA is not mentioned.",
#       "question": "What is a consolidated grade card?"
#     },
#     {
#       "answer": "An official transcript is an authentic document that includes updated results of all trimesters declared till date of application and it is signed by the Controller of Examinations.",
#       "question": "What is an official transcript?"
#     },
#     {
#       "answer": "The amount must have been deducted against any other outstanding fee. Contact student section for clarification.",
#       "question": "I have already paid the revaluation fees. But in ERP, it is seen as outstanding. What is the reason?"
#     },
#     {
#       "answer": "Do online payment for transcript. The payment details are mentioned on the website.(https://mitwpu.edu.in/examination/contact). Send the screenshot of payment to exam.helpdesk@mitwpu.edu.in",
#       "question": "What is the mode of payment for a transcript?"
#     },
#     {
#       "answer": "You  must  pay  online.  Payment  details  are  mentioned  on  website (https://mitwpu.edu.in/examination).   Send   the   screenshot   of   payment   to exam.helpdesk@mitwpu.edu.in.",
#       "question": "What is the mode of payment for Duplicate grade card?"
#     },
#     {
#       "answer": "You  must  pay  online.  Payment  details  are  mentioned  on  website (https://mitwpu.edu.in/examination).   Send   the   screenshot   of   payment   to exam.helpdesk@mitwpu.edu.in.Q When and how will I receive the consolidated grade card?",
#       "question": "What is the mode of payment for consolidated grade card?"
#     },
#     {
#       "answer": "Consolidated grade card shows revised result of only one trimester with revised GPA where as a transcript is a document that includes updated results of all trimesters with revised GPA and CGPA trimester wise.",
#       "question": "How is a Consolidated Grade Card different from a transcript?"
#     },
#     {
#       "answer": "Yes, it is compulsory to register for Convocation as per instructions and payment of registration fees.",
#       "question": "Is it compulsory to register for the Convocation ?"
#     }
#   ]
# }

# %%
q_id = r.json()["documents"][0]["question"]
print(q_id)
# Out:
# My name/Father's Name/Mother's name is incorrect on grade card. How do I get it corrected?

# %%
ret
# Out:
#     id                                           question  \
# 0    1            What if I need to know my correct CGPA?
# 1    2  I have cleared my backlog but the result sheet...
# 2    3  I have cleared my backlog, but the result on E...
# 3    4  What do I do if I have not received my grade c...
# 4    5  My name/Father's Name/Mother's name is incorre...
# ..  ..                                                ...
# 85  86  Can any of my family member collect Degree Cer...
# 86  87  I have registered and attended Convocation. Ho...
# 87  88  I need a set of grade cards attested? How do I...
# 88  89               Can I get my result on ERP attested?
# 89  90            In how many days can I get it attested?
#
#                                                answer  \
# 0   CGPA is seen on the grade card. The CGPA count...
# 1    GPA and CGPA are not mentioned on backlog gra...
# 2    Grade card shows first attempt GPA and CGPA o...
# 3   Grade cards should be collected from the stude...
# 4    Name correction on grade cards/PDC needs to b...
# ..                                                ...
# 85   Yes, that is permissible, provided you send a...
# 86   At first, you must complete the formalities r...
# 87  You    have    to    fill    the    student   ...
# 88           No. Results on ERP will not be attested.
# 89  You will get the grade cards attested in 2 wor...
#
#                           category
# 0                       grade card
# 1                       grade card
# 2                       grade card
# 3                       grade card
# 4   Corrections on grade card /PDC
# ..                             ...
# 85              Degree Certificate
# 86              Degree Certificate
# 87      Attestation of Grade Cards
# 88      Attestation of Grade Cards
# 89      Attestation of Grade Cards
#
# [90 rows x 4 columns]

# %%
trans
# Out:
#     id                        category  \
# 0    1                      grade card
# 1    2                      grade card
# 2    3                      grade card
# 3    4                      grade card
# 4    5  Corrections on grade card /PDC
# ..  ..                             ...
# 85  86              Degree Certificate
# 86  87              Degree Certificate
# 87  88      Attestation of Grade Cards
# 88  89      Attestation of Grade Cards
# 89  90      Attestation of Grade Cards
#
#                                          answer_hindi  \
# 0   ग्रेड कार्ड पर सीजीपीए लिखा होता है। परीक्षा अ...
# 1   बैकलॉग ग्रेड कार्ड पर जीपीए और सीजीपीए का उल्ल...
# 2   ग्रेड कार्ड केवल पहला प्रयास GPA और CGPA दिखात...
# 3   ग्रेड कार्ड आपके विभाग के छात्र अनुभाग से एकत्...
# 4   आपके विभाग के छात्र अनुभाग के कार्यालय में ईआर...
# ..                                                ...
# 85  हां, इसकी अनुमति है, बशर्ते आप परीक्षा विभाग क...
# 86  सबसे पहले, आपको अपनी ओर से लंबित मुद्दों से सं...
# 87  आपको छात्र सहायता फॉर्म भरना होगा (https://mit...
# 88         नहीं। ईआरपी पर परिणाम सत्यापित नहीं होंगे।
# 89  आपको 2 कार्य दिवसों में ग्रेड कार्ड सत्यापित म...
#
#                                        answer_marathi
# 0   ग्रेड कार्डवर CGPA दिसतो. परीक्षा अध्यादेश 202...
# 1   बॅकलॉग ग्रेड कार्डवर GPA आणि CGPA नमूद केलेले ...
# 2   ग्रेड कार्ड प्रथम प्रयत्न GPA आणि CGPA दर्शवित...
# 3   तुमच्या विभागातील विद्यार्थी विभागाकडून ग्रेड ...
# 4   तुमच्या विभागाच्या विद्यार्थी विभागाच्या कार्य...
# ..                                                ...
# 85  होय, ते अनुज्ञेय आहे, जर तुम्ही तुमच्या वतीने ...
# 86  प्रथम, आपण आपल्या शेवटी प्रलंबित समस्यांशी संब...
# 87  तुम्हाला विद्यार्थी सहाय्यता फॉर्म (https://mi...
# 88   नाही. ERP वरील परिणाम प्रमाणित केले जाणार नाहीत.
# 89  तुम्हाला 2 कामकाजाच्या दिवसांत ग्रेड कार्डे प्...
#
# [90 rows x 4 columns]

# %%
trans[trans["question"]==q_id]
# Out:
#    id  test                                           question  \
# 4   5     4  My name/Father's Name/Mother's name is incorre...
#
#                                               answer  \
# 4   Name correction on grade cards/PDC needs to b...
#
#                          category  \
# 4  Corrections on grade card /PDC
#
#                                         answer_hindi  \
# 4  आपके विभाग के छात्र अनुभाग के कार्यालय में ईआर...
#
#                                       answer_marathi
# 4  तुमच्या विभागाच्या विद्यार्थी विभागाच्या कार्य...

# %%
newtrans = pd.read_csv("translated_answers.csv")
newtrans
# Out:
#     id                                           question  \
# 0    0            What if I need to know my correct CGPA?
# 1    1  I have cleared my backlog but the result sheet...
# 2    2  I have cleared my backlog, but the result on E...
# 3    3  What do I do if I have not received my grade c...
# 4    4  My name/Father's Name/Mother's name is incorre...
# ..  ..                                                ...
# 85  85  Can any of my family member collect Degree Cer...
# 86  86  I have registered and attended Convocation. Ho...
# 87  87  I need a set of grade cards attested? How do I...
# 88  88               Can I get my result on ERP attested?
# 89  89            In how many days can I get it attested?
#
#                                                answer  \
# 0   CGPA is seen on the grade card. The CGPA count...
# 1    GPA and CGPA are not mentioned on backlog gra...
# 2    Grade card shows first attempt GPA and CGPA o...
# 3   Grade cards should be collected from the stude...
# 4    Name correction on grade cards/PDC needs to b...
# ..                                                ...
# 85   Yes, that is permissible, provided you send a...
# 86   At first, you must complete the formalities r...
# 87  You    have    to    fill    the    student   ...
# 88           No. Results on ERP will not be attested.
# 89  You will get the grade cards attested in 2 wor...
#
#                           category  \
# 0                       grade card
# 1                       grade card
# 2                       grade card
# 3                       grade card
# 4   Corrections on grade card /PDC
# ..                             ...
# 85              Degree Certificate
# 86              Degree Certificate
# 87      Attestation of Grade Cards
# 88      Attestation of Grade Cards
# 89      Attestation of Grade Cards
#
#                                          answer_hindi  \
# 0   ग्रेड कार्ड पर सीजीपीए लिखा होता है। परीक्षा अ...
# 1   बैकलॉग ग्रेड कार्ड पर जीपीए और सीजीपीए का उल्ल...
# 2   ग्रेड कार्ड केवल पहला प्रयास GPA और CGPA दिखात...
# 3   ग्रेड कार्ड आपके विभाग के छात्र अनुभाग से एकत्...
# 4   आपके विभाग के छात्र अनुभाग के कार्यालय में ईआर...
# ..                                                ...
# 85  हां, इसकी अनुमति है, बशर्ते आप परीक्षा विभाग क...
# 86  सबसे पहले, आपको अपनी ओर से लंबित मुद्दों से सं...
# 87  आपको छात्र सहायता फॉर्म भरना होगा (https://mit...
# 88         नहीं। ईआरपी पर परिणाम सत्यापित नहीं होंगे।
# 89  आपको 2 कार्य दिवसों में ग्रेड कार्ड सत्यापित म...
#
#                                        answer_marathi
# 0   ग्रेड कार्डवर CGPA दिसतो. परीक्षा अध्यादेश 202...
# 1   बॅकलॉग ग्रेड कार्डवर GPA आणि CGPA नमूद केलेले ...
# 2   ग्रेड कार्ड प्रथम प्रयत्न GPA आणि CGPA दर्शवित...
# 3   तुमच्या विभागातील विद्यार्थी विभागाकडून ग्रेड ...
# 4   तुमच्या विभागाच्या विद्यार्थी विभागाच्या कार्य...
# ..                                                ...
# 85  होय, ते अनुज्ञेय आहे, जर तुम्ही तुमच्या वतीने ...
# 86  प्रथम, आपण आपल्या शेवटी प्रलंबित समस्यांशी संब...
# 87  तुम्हाला विद्यार्थी सहाय्यता फॉर्म (https://mi...
# 88   नाही. ERP वरील परिणाम प्रमाणित केले जाणार नाहीत.
# 89  तुम्हाला 2 कामकाजाच्या दिवसांत ग्रेड कार्डे प्...
#
# [90 rows x 6 columns]

# %%
newtrans.drop('id', inplace=True,axis=1)

# %%
newtrans.to_csv("newtrans.csv")

# %%
with open('newtrans.csv') as infile, open('indexednewtrans.csv', 'w') as outfile:
    for idx, line in enumerate(infile):
        outfile.write(f'{idx},{line}')
